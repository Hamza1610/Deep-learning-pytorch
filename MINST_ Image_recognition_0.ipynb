# %% [markdown]
# # Image recognition using MINST dataset without class model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

# %%
transform = transforms.ToTensor() # Convert the datatset to 4-dimenentional

# %%
training_dataset = datasets.MNIST(root='/digits_data', train=True, download=True, transform=transform) 
testing_dataset = datasets.MNIST(root='/digits_data', train=False, download=True, transform=transform)

# %%
train_loader = DataLoader(dataset=training_dataset, batch_size=5, shuffle=True)
test_loader = DataLoader(dataset=training_dataset, batch_size=5, shuffle=False)

# %%
training_dataset
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: /digits_data
#     Split: Train
#     StandardTransform
# Transform: ToTensor()

# %%
testing_dataset
# Out:
# Dataset MNIST
#     Number of datapoints: 10000
#     Root location: /digits_data
#     Split: Test
#     StandardTransform
# Transform: ToTensor()

# %%
for (X_train, y_train)  in training_dataset: # I want to access only one item in the dataset for X_train and y_train
    break

# %%
X_train, y_train # one item from dataset to feed into model
# Out:
# (tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
# ...

# %%
X_train.shape # this is in 3 diemention i need to covert inot 4 demnesion before I can feed it into my model
# Out:
# torch.Size([1, 28, 28])

# %%
x = X_train.view(1,1,28,28) # reshape into 4 Demension

# %%
conv1 = nn.Conv2d(1, 8, 4, 1) # First convolution layer with 1 batch size 1 image and 28 by 28
conv2 = nn.Conv2d(8, 15, 3, 1) # Second convolution layer

# %%
x = F.relu(conv1(x))
x.shape
# Out:
# torch.Size([1, 8, 25, 25])

# %%
x = F.max_pool2d(x, 3, 2)
x.shape
# Out:
# torch.Size([1, 8, 12, 12])

# %%
x = F.relu(conv2(x))
x.shape
# Out:
# torch.Size([1, 15, 10, 10])

# %%
x = F.max_pool2d(x, 2, 2)
x.shape
# Out:
# torch.Size([1, 15, 4, 4])

# %%
fc1 = nn.Linear(15*4*4, 60) # First Linear layer: the input is 15 * 4 * 4 which is the demension of the x value
fc2 = nn.Linear(60, 20) # First Linear layer
# output_layer = nn.Linear(20, 9) # Output result

# %%
# Out:
# Linear(in_features=20, out_features=9, bias=True)
